# %% [markdown]
# # Citi Bike Data 2016 - 2018

# %%
# Dependencies & Setup
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Files to Load
july2016 = "201607-citibike-tripdata.csv"
july2017 = "201707-citibike-tripdata.csv"
july2018 = "201807-citibike-tripdata.csv"

# Read July 2016, 2017 & 2018 Citi Bike Data Files & Store into Pandas DataFrames
july2016_df = pd.read_csv(july2016, encoding="ISO-8859-1")
july2017_df = pd.read_csv(july2017, encoding="ISO-8859-1")
july2018_df = pd.read_csv(july2018, encoding="ISO-8859-1")

# %%
july2018_df["Start Time"]
# Out:
# 0        08:39.9
# 1        09:07.5
# 2        14:45.7
# 3        25:12.4
# 4        07:44.1
#           ...
# 42263    51:08.1
# 42264    15:37.0
# 42265    45:01.5
# 42266    06:19.6
# 42267    06:02.3
# Name: Start Time, Length: 42268, dtype: object

# %%
combined_july_df = pd.concat([july2016_df, july2017_df, july2018_df])
combined_july_df
# Out:
#        Trip Duration      Start Time       Stop Time  Start Station ID  \
# 0                964  1/07/2016 0:06  1/07/2016 0:22              3185
# 1                472  1/07/2016 0:06  1/07/2016 0:14              3185
# 2                565  1/07/2016 0:10  1/07/2016 0:20              3199
# 3                413  1/07/2016 0:17  1/07/2016 0:24              3195
# 4                436  1/07/2016 0:37  1/07/2016 0:44              3202
# ...              ...             ...             ...               ...
# 42263            993         51:08.1         07:41.6              3694
# 42264            311         15:37.0         20:48.1              3694
# 42265            795         45:01.5         58:16.6              3694
# 42266            918         06:19.6         21:38.0              3694
# 42267           1956         06:02.3         38:39.0              3694
#
#       Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0              City Hall               40.717732               -74.043845
# 1              City Hall               40.717732               -74.043845
# 2           Newport Pkwy               40.728745               -74.032108
# 3                Sip Ave               40.730743               -74.063784
# 4           Newport PATH               40.727224               -74.033759
# ...                  ...                     ...                      ...
# 42263     Jackson Square               40.711130               -74.078900
# 42264     Jackson Square               40.711130               -74.078900
# 42265     Jackson Square               40.711130               -74.078900
# 42266     Jackson Square               40.711130               -74.078900
# 42267     Jackson Square               40.711130               -74.078900
#
#        End Station ID       End Station Name  End Station Latitude  \
# 0                3199           Newport Pkwy             40.728745
# 1                3192     Liberty Light Rail             40.711242
# 2                3199           Newport Pkwy             40.728745
# 3                3209           Brunswick St             40.724176
# 4                3203          Hamilton Park             40.727596
# ...               ...                    ...                   ...
# 42263            3211             Newark Ave             40.721525
# 42264            3694         Jackson Square             40.711130
# 42265            3225  Baldwin at Montgomery             40.723659
# 42266            3195                Sip Ave             40.730743
# 42267            3280            Astor Place             40.719282
#
#        End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0                 -74.032108    24706  Subscriber      1987.0       1
# 1                 -74.055701    24504  Subscriber      1981.0       2
# 2                 -74.032108    24655  Subscriber      1990.0       1
# 3                 -74.050656    24446  Subscriber      1983.0       1
# 4                 -74.044247    24408  Subscriber      1988.0       2
# ...                      ...      ...         ...         ...     ...
# 42263             -74.046305    26299  Subscriber      1991.0       2
# 42264             -74.078900    26201    Customer      1969.0       0
# 42265             -74.064194    26225  Subscriber      1961.0       1
# 42266             -74.063784    26187  Subscriber      1986.0       2
# 42267             -74.071262    26201  Subscriber      1982.0       2
#
# [100277 rows x 15 columns]

# %%
combined_july_df.drop(columns=["Start Time", "Stop Time"], inplace=True)

# %%
combined_july_df
# Out:
#        Trip Duration  Start Station ID Start Station Name  \
# 0                964              3185          City Hall
# 1                472              3185          City Hall
# 2                565              3199       Newport Pkwy
# 3                413              3195            Sip Ave
# 4                436              3202       Newport PATH
# ...              ...               ...                ...
# 42263            993              3694     Jackson Square
# 42264            311              3694     Jackson Square
# 42265            795              3694     Jackson Square
# 42266            918              3694     Jackson Square
# 42267           1956              3694     Jackson Square
#
#        Start Station Latitude  Start Station Longitude  End Station ID  \
# 0                   40.717732               -74.043845            3199
# 1                   40.717732               -74.043845            3192
# 2                   40.728745               -74.032108            3199
# 3                   40.730743               -74.063784            3209
# 4                   40.727224               -74.033759            3203
# ...                       ...                      ...             ...
# 42263               40.711130               -74.078900            3211
# 42264               40.711130               -74.078900            3694
# 42265               40.711130               -74.078900            3225
# 42266               40.711130               -74.078900            3195
# 42267               40.711130               -74.078900            3280
#
#             End Station Name  End Station Latitude  End Station Longitude  \
# 0               Newport Pkwy             40.728745             -74.032108
# 1         Liberty Light Rail             40.711242             -74.055701
# 2               Newport Pkwy             40.728745             -74.032108
# 3               Brunswick St             40.724176             -74.050656
# 4              Hamilton Park             40.727596             -74.044247
# ...                      ...                   ...                    ...
# 42263             Newark Ave             40.721525             -74.046305
# 42264         Jackson Square             40.711130             -74.078900
# 42265  Baldwin at Montgomery             40.723659             -74.064194
# 42266                Sip Ave             40.730743             -74.063784
# 42267            Astor Place             40.719282             -74.071262
#
#        Bike ID   User Type  Birth Year  Gender
# 0        24706  Subscriber      1987.0       1
# 1        24504  Subscriber      1981.0       2
# 2        24655  Subscriber      1990.0       1
# 3        24446  Subscriber      1983.0       1
# 4        24408  Subscriber      1988.0       2
# ...        ...         ...         ...     ...
# 42263    26299  Subscriber      1991.0       2
# 42264    26201    Customer      1969.0       0
# 42265    26225  Subscriber      1961.0       1
# 42266    26187  Subscriber      1986.0       2
# 42267    26201  Subscriber      1982.0       2
#
# [100277 rows x 13 columns]

# %%
combined_july_df["User Type"].value_counts()
# Out:
# Subscriber    91897
# Customer       8374
# Name: User Type, dtype: int64

# %%
# Combine All Three July DataFrames from 2016-2018 Into Single DataFrame
# combined_july_df = july2016_df.append([july2017_df, july2018_df], ignore_index=True)
# combined_july_df.head()
# Out:
#    Trip Duration      Start Time       Stop Time  Start Station ID  \
# 0            964  1/07/2016 0:06  1/07/2016 0:22              3185
# 1            472  1/07/2016 0:06  1/07/2016 0:14              3185
# 2            565  1/07/2016 0:10  1/07/2016 0:20              3199
# 3            413  1/07/2016 0:17  1/07/2016 0:24              3195
# 4            436  1/07/2016 0:37  1/07/2016 0:44              3202
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0          City Hall               40.717732               -74.043845
# 1          City Hall               40.717732               -74.043845
# 2       Newport Pkwy               40.728745               -74.032108
# 3            Sip Ave               40.730743               -74.063784
# 4       Newport PATH               40.727224               -74.033759
#
#    End Station ID    End Station Name  End Station Latitude  \
# 0            3199        Newport Pkwy             40.728745
# 1            3192  Liberty Light Rail             40.711242
# 2            3199        Newport Pkwy             40.728745
# 3            3209        Brunswick St             40.724176
# 4            3203       Hamilton Park             40.727596
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0             -74.032108    24706  Subscriber      1987.0       1
# 1             -74.055701    24504  Subscriber      1981.0       2
# 2             -74.032108    24655  Subscriber      1990.0       1
# 3             -74.050656    24446  Subscriber      1983.0       1
# 4             -74.044247    24408  Subscriber      1988.0       2

# %%
# Rename Columns
# combined_july_df = combined_july_df.rename(columns={"tripduration": "Trip Duration",
#                                             "starttime": "Start Time",
#                                             "stoptime": "Stop Time",
#                                             "start station id": "Start Station ID",
#                                             "start station name": "Start Station Name",
#                                             "start station latitude": "Start Station Latitude",
#                                             "start station longitude": "Start Station Longitude",
#                                             "end station id": "End Station ID",
#                                             "end station name": "End Station Name",
#                                             "end station latitude": "End Station Latitude",
#                                             "end station longitude": "End Station Longitude",
#                                             "bikeid": "Bike ID",
#                                             "usertype": "User Type",
#                                             "birth year": "Birth Year",
#                                             "gender": "Gender"
#                                            })
# combined_july_df.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0          964.0  2016-07-01 00:06:09  2016-07-01 00:22:14            3185.0
# 1          472.0  2016-07-01 00:06:44  2016-07-01 00:14:37            3185.0
# 2          565.0  2016-07-01 00:10:39  2016-07-01 00:20:05            3199.0
# 3          413.0  2016-07-01 00:17:22  2016-07-01 00:24:15            3195.0
# 4          436.0  2016-07-01 00:37:31  2016-07-01 00:44:48            3202.0
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0          City Hall               40.717732               -74.043845
# 1          City Hall               40.717732               -74.043845
# 2       Newport Pkwy               40.728745               -74.032108
# 3            Sip Ave               40.730743               -74.063784
# 4       Newport PATH               40.727224               -74.033759
#
#   End Station ID    End Station Name  End Station Latitude  ...  \
# 0         3199.0        Newport Pkwy             40.728745  ...
# 1         3192.0  Liberty Light Rail             40.711242  ...
# 2         3199.0        Newport Pkwy             40.728745  ...
# 3         3209.0        Brunswick St             40.724176  ...
# 4         3203.0       Hamilton Park             40.727596  ...
#
#    Start Station Latitude  Start Station Longitude End Station ID  \
# 0                     NaN                      NaN            NaN
# 1                     NaN                      NaN            NaN
# 2                     NaN                      NaN            NaN
# 3                     NaN                      NaN            NaN
# 4                     NaN                      NaN            NaN
#
#    End Station Name  End Station Latitude  End Station Longitude Bike ID  \
# 0               NaN                   NaN                    NaN     NaN
# 1               NaN                   NaN                    NaN     NaN
# 2               NaN                   NaN                    NaN     NaN
# 3               NaN                   NaN                    NaN     NaN
# 4               NaN                   NaN                    NaN     NaN
#
#   User Type  Birth Year Gender
# 0       NaN         NaN    NaN
# 1       NaN         NaN    NaN
# 2       NaN         NaN    NaN
# 3       NaN         NaN    NaN
# 4       NaN         NaN    NaN
#
# [5 rows x 30 columns]

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
# combined_july_df["Start Time"] = pd.to_datetime(combined_july_df["Start Time"])
# combined_july_df["Stop Time"] = pd.to_datetime(combined_july_df["Stop Time"])
# combined_july_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#
# ~\anaconda3.1\lib\site-packages\six.py in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 25:12.4
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13940/1550943795.py in <module>
#       1 # Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
# ----> 2 combined_july_df["Start Time"] = pd.to_datetime(combined_july_df["Start Time"])
#       3 combined_july_df["Stop Time"] = pd.to_datetime(combined_july_df["Stop Time"])
#       4 combined_july_df.head()
#
# ~\anaconda3.1\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     881                 result = result.tz_localize(tz)  # type: ignore[call-arg]
#     882     elif isinstance(arg, ABCSeries):
# --> 883         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     884         if not cache_array.empty:
#     885             result = arg.map(cache_array)
#
# ~\anaconda3.1\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     193         unique_dates = unique(arg)
#     194         if len(unique_dates) < len(arg):
# --> 195             cache_dates = convert_listlike(unique_dates, format)
#     196             cache_array = Series(cache_dates, index=unique_dates)
#     197             # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# ~\anaconda3.1\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# ~\anaconda3.1\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191             return values.view("i8"), tz_parsed
#    2192         except (ValueError, TypeError):
# -> 2193             raise err
#    2194
#    2195     if tz_parsed is not None:
#
# ~\anaconda3.1\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~\anaconda3.1\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# ~\anaconda3.1\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#     653         if not ignoretz:
#
# ~\anaconda3.1\lib\site-packages\six.py in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 25:12.4

# %%
# combined_july_df["Start Time"]
# Out:
# 0        1/07/2016 0:06
# 1        1/07/2016 0:06
# 2        1/07/2016 0:10
# 3        1/07/2016 0:17
# 4        1/07/2016 0:37
#               ...
# 42263           51:08.1
# 42264           15:37.0
# 42265           45:01.5
# 42266           06:19.6
# 42267           06:02.3
# Name: Start Time, Length: 100277, dtype: object

# %%
combined_july_df.dtypes
# Out:
# Trip Duration                int64
# Start Station ID             int64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID               int64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                      int64
# User Type                   object
# Birth Year                 float64
# Gender                       int64
# dtype: object

# %%
# Save Combined DataFrames to CSV
combined_july_df.to_csv("three-year-july-citibike-tripdata.csv", index=False, header=True)
